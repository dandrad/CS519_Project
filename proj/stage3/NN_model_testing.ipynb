# %%
from load_and_reduce import load_and_reduce


from sklearn.ensemble import GradientBoostingRegressor
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler

# %%
intake_path = "Austin_Animal_Center_Intakes.csv"
outcome_path = "Austin_Animal_Center_Outcomes.csv"

X, y = load_and_reduce(intake_path, outcome_path, coding = "onehot", scale = True)

X.head()
# Out:
# Intake Type
# 5
#
# Intake Condition
# 10
#
# Animal Type
# 2
#
# Outcome Type
# 9
#
# Sex upon Outcome
# 5
#
# Sex upon Intake
# 5
#     Age (Days)  Intake Type_Abandoned  Intake Type_Euthanasia Request  \
# 1          7.0                      0                               0
# 2          7.0                      0                               0
# 3          7.0                      0                               0
# 13       365.0                      0                               0
# 14      2555.0                      0                               0
#
#     Intake Type_Owner Surrender  Intake Type_Public Assist  Intake Type_Stray  \
# 1                             0                          0                  1
# 2                             0                          0                  1
# 3                             0                          0                  1
# 13                            0                          0                  1
# ...

# %%
X_copy = X.copy()
y_copy = y.copy()

nattributes = X.shape[1]
ninstances = X.shape[0]

# %%
def GetModel():
    
    model = Sequential()
    
    model.add(Dense(nattributes, input_dim=nattributes,activation='relu')) 
    #model.add(Dense(64*4, activation='relu'))
    #model.add(Dense(64*4, activation='relu'))
    #model.add(Dense(64*2, activation='relu'))
    #model.add(Dense(64, activation='relu')) 
    model.add(Dense(64/2,activation='relu')) 
    model.add(Dense(16,activation='relu'))
    model.add(Dense(1,activation='linear'))
    model.compile(loss="mean_squared_error", optimizer="adam") 
    
    return model

# %%
regressor = KerasRegressor(build_fn=GetModel,epochs=50,batch_size=50)
regressor.fit(X,y)
# Out:
# Epoch 1/100
# 2061/2061 [==============================] - 2s 564us/step - loss: 2184.7837
# Epoch 2/100
# 2061/2061 [==============================] - 1s 494us/step - loss: 1902.9938
# Epoch 3/100
# 2061/2061 [==============================] - 1s 505us/step - loss: 1773.2929
# Epoch 4/100
# 2061/2061 [==============================] - 1s 478us/step - loss: 1812.2313
# Epoch 5/100
# 2061/2061 [==============================] - 1s 465us/step - loss: 1754.5406
# Epoch 6/100
# 2061/2061 [==============================] - 1s 470us/step - loss: 1693.3353
# Epoch 7/100
# 2061/2061 [==============================] - 1s 458us/step - loss: 1873.9416
# Epoch 8/100
# 2061/2061 [==============================] - 1s 455us/step - loss: 1716.7443
# Epoch 9/100
# 2061/2061 [==============================] - 1s 475us/step - loss: 1758.8991
# Epoch 10/100
# 2061/2061 [==============================] - 1s 485us/step - loss: 1724.2403
# Epoch 11/100
# ...
